# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyaly-13/Bootcamp/blob/main/Session2GLA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Priyal")
# Out:
# Hello Priyal

# %%
print("hello dudu")
# Out:
# hello dudu
